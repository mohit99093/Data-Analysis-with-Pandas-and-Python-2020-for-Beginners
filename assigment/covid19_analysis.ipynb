# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
co_data = pd.read_csv("covid19_data_mar.csv")

# %%
co_data.head()
# Out:
#     id  case_in_country reporting date          location country  gender  \
# 0  195              NaN      1/27/2020             Hubei   China  female
# 1  196              NaN      1/27/2020             Hubei   China  female
# 2  197              NaN      1/27/2020          Shandong   China    male
# 3  237              1.0      1/15/2020          Kanagawa   Japan    male
# 4  241              5.0      1/28/2020  Aichi Prefecture   Japan    male
#
#     age symptom_onset  If_onset_approximated hosp_visit_date exposure_start  \
# 0  28.0      1/7/2020                    0.0       1/10/2020            NaN
# 1  51.0           NaN                    NaN       1/11/2020            NaN
# 2  37.0           NaN                    NaN       1/17/2020            NaN
# 3  35.0      1/3/2020                    0.0        1/6/2020            NaN
# 4  45.0     1/22/2020                    0.0       1/26/2020            NaN
#
# ...

# %%
co_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 19 columns):
# id                       270 non-null int64
# case_in_country          267 non-null float64
# reporting date           270 non-null object
# location                 270 non-null object
# country                  270 non-null object
# gender                   269 non-null object
# age                      265 non-null float64
# symptom_onset            252 non-null object
# If_onset_approximated    252 non-null float64
# hosp_visit_date          214 non-null object
# exposure_start           32 non-null object
# exposure_end             79 non-null object
# incubationdays           270 non-null object
# hospitaldays             270 non-null object
# visiting Wuhan           270 non-null int64
# from Wuhan               270 non-null int64
# death                    6 non-null object
# recovered                36 non-null object
# symptom                  270 non-null object
# ...

# %%
co_data.isnull()
# Out:
#         id  case_in_country  reporting date  location  country  gender    age  \
# 0    False             True           False     False    False   False  False
# 1    False             True           False     False    False   False  False
# 2    False             True           False     False    False   False  False
# 3    False            False           False     False    False   False  False
# 4    False            False           False     False    False   False  False
# 5    False            False           False     False    False   False  False
# 6    False            False           False     False    False   False  False
# 7    False            False           False     False    False   False  False
# 8    False            False           False     False    False   False  False
# 9    False            False           False     False    False   False  False
# 10   False            False           False     False    False   False  False
# ...

# %%
co_data.isnull().sum()

# %%
round(100*(co_data.isnull().sum()/len(co_data.index)), 2)

# %%
co_data['age'].describe()
# Out:
# count    265.000000
# mean      53.301887
# std       17.563936
# min        4.000000
# 25%       43.000000
# 50%       55.000000
# 75%       65.000000
# max       89.000000
# Name: age, dtype: float64

# %%
co_data.loc[np.isnan(co_data['age']), ['age']] = co_data['age'].mean()

# %%
sns.boxplot(y=co_data['age'])
plt.title('age boxplot')
plt.show()

# %%
sns.distplot(co_data['age'])
plt.show()

# %%
sns.countplot(x="gender", data=co_data)
plt.title("gender")
plt.show()

# %%
co_data.head()
co_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     270 non-null    int64
#  1   case_in_country        267 non-null    float64
#  2   reporting date         270 non-null    object
#  3   location               270 non-null    object
#  4   country                270 non-null    object
#  5   gender                 269 non-null    object
#  6   age                    265 non-null    float64
#  7   symptom_onset          252 non-null    object
#  8   If_onset_approximated  252 non-null    float64
#  9   hosp_visit_date        214 non-null    object
#  10  exposure_start         32 non-null     object
#  11  exposure_end           79 non-null     object
#  12  incubationdays         270 non-null    object
#  13  hospitaldays           270 non-null    object
# ...

# %%
#co_data['incubationdays']=co_data['incubationdays'].float()

co_data['incubationdays'] = pd.to_numeric(co_data['incubationdays'], errors='coerce')
co_data
# Out:
#        id  case_in_country reporting date          location      country  \
# 0     195              NaN      1/27/2020             Hubei        China
# 1     196              NaN      1/27/2020             Hubei        China
# 2     197              NaN      1/27/2020          Shandong        China
# 3     237              1.0      1/15/2020          Kanagawa        Japan
# 4     241              5.0      1/28/2020  Aichi Prefecture        Japan
# ..    ...              ...            ...               ...          ...
# 265   964             93.0      2/27/2020         Hong Kong    Hong Kong
# 266   993              1.0       2/2/2020            Manila  Phillipines
# 267   996              1.0      1/29/2020           Lapland      Finland
# 268  1007             11.0      2/26/2020         Barcelona        Spain
# 269  1031              1.0      1/31/2020         Jonkoping       Sweden
#
#      gender   age symptom_onset  If_onset_approximated hosp_visit_date  \
# ...

# %%
co_data['incubationdays'].describe()
# Out:
# count    31.000000
# mean     10.064516
# std       8.053718
# min      -1.000000
# 25%       5.500000
# 50%       8.000000
# 75%      11.000000
# max      34.000000
# Name: incubationdays, dtype: float64

# %%
sns.boxplot(y=co_data['incubationdays'])
plt.title('incubationdays boxplot')
plt.show()

# %%
co_data.loc[np.isnan(co_data['incubationdays']), ['incubationdays']] = co_data['incubationdays'].mean()

# %%
#incubationdays

# sns.distplot()
sns.distplot(co_data['incubationdays'], hist = False, rug = True, rug_kws = {'color' : 'r'})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-3a61605c6a97> in <module>
#       2
#       3 # sns.distplot()
# ----> 4 sns.distplot(co_data['incubationdays'], hist = False, rug = True, rug_kws = {'color' : 'r'})
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
# ...

# %%
#hospitaldays


co_data['hospitaldays'] = pd.to_numeric(co_data['hospitaldays'], errors='coerce')

# %%
sns.boxplot(y=co_data['hospitaldays'])
plt.title('hospitaldays boxplot')
plt.show()

# hospitalised we cant conclude anything

# %%
co_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     270 non-null    int64
#  1   case_in_country        267 non-null    float64
#  2   reporting date         270 non-null    object
#  3   location               270 non-null    object
#  4   country                270 non-null    object
#  5   gender                 269 non-null    object
#  6   age                    265 non-null    float64
#  7   symptom_onset          252 non-null    object
#  8   If_onset_approximated  252 non-null    float64
#  9   hosp_visit_date        214 non-null    object
#  10  exposure_start         32 non-null     object
#  11  exposure_end           79 non-null     object
#  12  incubationdays         270 non-null    float64
#  13  hospitaldays           200 non-null    float64
# ...

# %%
co_data['symptom'].astype('category').value_counts()
# Out:
# fever                          73
# fever, cough                   36
# cough                          14
# fever, malaise                  7
# fever, cough, malaise           6
#                                ..
# fever, sore throat, cough       1
# fever, sore throat, malaise     1
# fever, thirst                   1
# fever, vomiting, diarrhea       1
# chest discomfort                1
# Name: symptom, Length: 108, dtype: int64

# %%
co_data_symptoms=co_data.loc[ ( co_data['symptom'] == 'fever') | ( co_data['symptom'] == 'fever, cough') |( co_data['symptom'] == 'fever,cough,malaise')
            |( co_data['symptom'] == 'fever, malaise') |( co_data['symptom'] == 'cough') , :]

# %%
sns.countplot(x="symptom", data=co_data_symptoms)
plt.title("symptom")
plt.show()
